# %% [markdown]
# <a href="https://colab.research.google.com/github/sabikunjubly/python_course-ML-/blob/main/python_Course(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hallo world")
# Out:
# Hallo world

# %%
print("Hallo\n", "world")
# Out:
# Hallo
#  world

# %%
print("skill\n","\tMorph")
# Out:
# skill
#  	Morph

# %%
# variable
num = 123
print("value :",num)
# Out:
# value : 123
